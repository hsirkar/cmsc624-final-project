# %%
data = """
                    Low contention Read only (5 records)
        -------------------------------------------------------------------
 Serial     9797.69     996.866     99.7877     307.725 
 Locking A  58595.8     6931.39     721.338     2143.37 
 Locking B  60211.7     7020.33     725.836     2217.74 
 OCC        66110.4     6821.35     725.304     2207.29 
 OCC-P      67149.8     7166.73     732.699     2283.65 
 MVCC       64086.4     6958.91     720.181     2074.83 
 Calvin     60378.1     7084.18     689.261     2149.72 
 Calvin_I   64922.6     6551.55     709.362     2242.63 
                    Low contention Read only (30 records)
        -------------------------------------------------------------------
 Serial     8711.05     984.985     99.5749     290.988 
 Locking A  32286.3     6806.52     682.397     2178.98 
 Locking B  27604.4     6915.97     723.495     2273.64 
 OCC        54004.3     6741.61     726.475     2087.41 
 OCC-P      58989.4     6341.84     720.063     2235.9  
 MVCC       51077.2     6777.22     709.264     2112.17 
 Calvin     31857.7     6695.48     723.942     2369.13 
 Calvin_I   46888.6     6725.26     715.993     2225.18 
                    High contention Read only (5 records)
        -------------------------------------------------------------------
 Serial     9913.58     995.69      99.9483     293.219 
 Locking A  21618.8     2994.58     316.971     702.431 
 Locking B  62619.9     7001.13     721.047     2314.32 
 OCC        60747.4     6958.5      730.399     2165.31 
 OCC-P      65990.9     7044.34     710.48      2261.79 
 MVCC       66749.3     6989.29     744.759     2354.62 
 Calvin     62983.1     6999.4      715.147     2237.94 
 Calvin_I   66173.8     6918.06     727.146     2265.9  
                    High contention Read only (30 records)
        -------------------------------------------------------------------
 Serial     9456.95     992.773     99.8453     336.621 
 Locking A  7803.85     974.048     99.4575     281.796 
 Locking B  60776.6     6865.17     711.955     2332.64 
 OCC        59445.3     6873.69     722.905     2286.41 
 OCC-P      58325.9     6382.77     729.112     2337.16 
 MVCC       59333.1     7092.66     693.326     2284.16 
 Calvin     36315.1     6819.18     725.574     2206.84 
 Calvin_I   53151.6     6876.27     695.728     2206.81 
                    Low contention read-write (5 records)
        -------------------------------------------------------------------
 Serial     9550.69     991.358     99.9138     335.869 
 Locking A  62464.5     6631.7      730.056     2106.67 
 Locking B  60963.7     6910.25     715.742     2167.47 
 OCC        63631.2     7164.69     718.042     2159.47 
 OCC-P      63522.9     6903.52     722.84      2293.65 
 MVCC       59979.5     6907.81     714.96      2267.47 
 Calvin     60075.4     6962.07     720.551     2277.11 
 Calvin_I   64187.8     6937.11     722.993     2275.8  
                    Low contention read-write (10 records)
        -------------------------------------------------------------------
 Serial     9238.2      984.465     99.8365     293.465 
 Locking A  55239       6674.77     653.032     2224.44 
 Locking B  54181.8     6891.76     720.335     2154.53 
 OCC        60732       6953.38     708.262     2305.65 
 OCC-P      61567.1     6916.93     720.291     2142.14 
 MVCC       59218.6     7146.85     721.761     2302.66 
 Calvin     53630.6     6931.9      735.951     2305.3  
 Calvin_I   60499.6     6878.01     711.296     2076.34 
                    High contention read-write (5 records)
        -------------------------------------------------------------------
 Serial     9784.75     995.387     99.9001     319.843 
 Locking A  24280.5     3030.77     296.804     719.329 
 OCC-P    	44978		4615.32		573.036		1592.95	
 Calvin-C 	49649.9		5266.62		621.347		1657.71	
Calvin-CI 	46069.7		5354.04		578.023		1940.89	
 Calvin-E 	15690.4		4906.07		429.588		696.841	

		            Low contention read-write (5 records)
		-------------------------------------------------------------------
 Serial   	9348.81		991.974		99.9101		305.312	
 Locking A	44775.6		4454.39		616.517		1760.34	
 Locking B	45283.5		4471.26		604.267		1608.82	
 OCC      	42714.6		4151.6		576.583		1666.53	
 OCC-P    	44632.9		4600.8		548.099		1746.93	
 Calvin-C 	36734.2		5928.23		596.589		1342.72	
Calvin-CI 	55869.6		5913.77		539.813		1705.29	
 Calvin-E 	15811.4		3719.73		401.229		793.61	

		            Low contention read-write (10 records)
		-------------------------------------------------------------------
 Serial   	8897.85		984.942		99.8059		323.679	
 Locking A	41470.3		4461.16		631.852		1563.71	
 Locking B	42399.6		4532.74		551.296		1612.98	
 OCC      	43099.6		4230.62		614.835		1647.14	
 OCC-P    	41686.6		4573.48		592.859		1682.86	
 Calvin-C 	42089.5		5369.25		493.507		1525.25	
Calvin-CI 	47758.8		4898.71		568.224		1540.47	
 Calvin-E 	13800.9		4847.14		437.467		767.505	

		            High contention read-write (5 records)
		-------------------------------------------------------------------
 Serial   	9814.99		997.016		99.2087		299.653	
 Locking A	19483.6		2424.3		275.554		634.753	
 Locking B	19752.5		2491.69		259.801		570.747	
 OCC      	47263.7		4592.58		540.728		1633.2	
 OCC-P    	46790.7		4374.95		579.595		1768.5	
 Calvin-C 	38651.5		4427.57		569.673		1695.04	
Calvin-CI 	52859.1		4396.52		544.784		1457.08	
 Calvin-E 	15385.6		4991.45		380.46		892.77	

		            High contention read-write (10 records)
		-------------------------------------------------------------------
 Serial   	9707.85		996.114		99.9358		297.828	
 Locking A	8823.04		1294.62		135.069		355.095	
 Locking B	8777.63		1256.6		131.118		342.882	
 OCC      	45878.2		4563.51		526.672		1481.15	
 OCC-P    	43417		4483.64		593.688		1721.47	
 Calvin-C 	52490.9		4440.57		493.881		1685.07	
Calvin-CI 	52892.6		5930.16		444.402		1824.92	
 Calvin-E 	16415		5041.94		483.6		798.608	

		            High contention mixed read only/read-write
		-------------------------------------------------------------------
 Serial   	12011.3		1213.81		131.033		397.027	
 Locking A	7056.93		1174.62		117.325		399.817	
 Locking B	19425.4		2879.47		315.28		661.992	
 OCC      	34608.8		3440.08		376.008		747.678	
 OCC-P    	37046.4		3591.66		400.139		828.591	
 Calvin-C 
 """

# %%
current_case = ""
results = []

for line in data.split("\n"):
    if not line.strip():
        continue
    if "-----" in line:
        continue
    if line.startswith("              "):
        current_case = line.strip()
        print(current_case)
    else:
        line=line.strip()
        row = []
        tmp = [s.strip() for s in line.split("  ")]
        row.append(current_case)
        row.append(tmp[0])
        row.extend([float(x) for x in tmp[1:] if x != ""])
        results.append(row)
        

# results
# Out:
# Low contention Read only (5 records)
# Low contention Read only (30 records)
# High contention Read only (5 records)
# High contention Read only (30 records)
# Low contention read-write (5 records)
# Low contention read-write (10 records)
# High contention read-write (5 records)
# High contention read-write (10 records)
# High contention mixed read only/read-write

# %%
current_case = ""
results2 = []

for line in data2.split("\n"):
    if not line.strip():
        continue
    if "-----" in line:
        continue
    if line.startswith("		   "):
        current_case = line.strip()
        print(current_case)
    else:
        line=line.strip()
        row = []
        tmp = [s.strip() for s in line.split("\t")]
        if tmp[0] != "Calvin-E":
            continue
        row.append(current_case)
        row.append(tmp[0])
        row.extend([float(x) for x in tmp[1:] if x != ""])
        results2.append(row)

# results2
# Out:
# Low contention Read only (5 records)
# Low contention Read only (30 records)
# High contention Read only (5 records)
# High contention Read only (30 records)
# Low contention read-write (5 records)
# Low contention read-write (10 records)
# High contention read-write (5 records)
# High contention read-write (10 records)
# High contention mixed read only/read-write

# %%
results = results + results2

# %%
df = pd.DataFrame(results)
df.columns = ["Workload", "Mode", "0.1ms", "1ms", "10ms", "(0.1ms, 1ms, 10ms)"]
df = df.set_index(["Workload", "Mode"])
df.sort_values("Workload", kind='stable')
# Out:
#                                                      0.1ms       1ms  \
# Workload                               Mode
# High contention Read only (30 records) Serial      9456.95   992.773
#                                        Locking A   7803.85   974.048
#                                        Locking B  60776.60  6865.170
#                                        OCC        59445.30  6873.690
#                                        OCC-P      58325.90  6382.770
# ...                                                    ...       ...
# Low contention read-write (5 records)  MVCC       59979.50  6907.810
#                                        Calvin     60075.40  6962.070
#                                        Calvin_I   64187.80  6937.110
#                                        Calvin-E   15811.40  3719.730
#                                        Calvin-E   15811.40  3719.730
#
#                                                       10ms  (0.1ms, 1ms, 10ms)
# ...

# %%
avg = df[["(0.1ms, 1ms, 10ms)"]]
avg
# Out:
#                                                    (0.1ms, 1ms, 10ms)
# Workload                                Mode
# Low contention Read only (5 records)    Serial                307.725
#                                         Locking A            2143.370
#                                         Locking B            2217.740
#                                         OCC                  2207.290
#                                         OCC-P                2283.650
# ...                                                               ...
# High contention Read only (30 records)  Calvin-E              696.841
# Low contention read-write (5 records)   Calvin-E              793.610
# Low contention read-write (10 records)  Calvin-E              767.505
# High contention read-write (5 records)  Calvin-E              892.770
# High contention read-write (10 records) Calvin-E              798.608
#
# [88 rows x 1 columns]

# %%
df = df.loc[[
    # "Low contention Read only (5 records)",
    "Low contention Read only (30 records)",
    # "High contention Read only (5 records)",
    "High contention Read only (30 records)",
    # "Low contention read-write (5 records)",
    "Low contention read-write (10 records)",
    # "High contention read-write (5 records)",
    "High contention read-write (10 records)",
    "High contention mixed read only/read-write"
]]

# %%
import seaborn as sns

# Reset index for Seaborn
df2 = df.reset_index()

# Plot using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Workload', y='(0.1ms, 1ms, 10ms)', hue='Mode', data=df2)
# plt.title('Workload Comparison by Mode')
plt.xlabel('Workload')
plt.ylabel('Time (ms)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Workload')
plt.tight_layout()
plt.show()

# %%
# !pip install seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 5.8 MB/s eta 0:00:003.9 MB/s eta 0:00:01
# ...

# %%
avg.plot.bar()
# Out:
# <Axes: xlabel='Workload,Mode'>
